# %%
import base64
import requests
import os
import time

# OpenAI API Key
api_key = "**************"

# Function to encode the image
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

# Path to your image
input_dir = "PPE-detection-no-ppe-v2/test/images"
output_dir = "output/gpt4o/working/test_set"
os.makedirs(output_dir, exist_ok=True)
i = 0
for file_name in os.listdir(input_dir):
    i+=1
    filepath = os.path.join(input_dir, file_name)
    print(f'elaboro {file_name} elemento numero {i}')
    base64_image = encode_image(filepath)
    headers = {
      "Content-Type": "application/json",
      "Authorization": f"Bearer {api_key}"
    }
    payload = {
      "model": "gpt-4o",
      "messages": [
        {
          "role": "user",
          "content": [
            {
              "type": "text",
              "text": ("Are there PPEs in the scene? "
                    "Are there blue, orange or yellow high visibility vests in the scene? "
                    "Are there gloves? "
                    "Are there security boots? "
                    "Are there hard hats? "
                    "Count people who doesn't wear PPE in the picture, I'll make you an example:\n"
                    "    - People: {number of people}\n"
                    "    - no-Hard_hats: {number of Hard_hats}\n"
                    "    - no-Gloves: {number of Gloves}\n"
                    "    - no-Reflective_vests: {number of Reflective_vests}\n"
                    "    - no-Security_boots: {number of Security_boots}\n")
            },
            {
              "type": "image_url",
              "image_url": {
                "url": f"data:image/jpeg;base64,{base64_image}"
              }
            }
          ]
        }
      ],
      "max_tokens": 500
    }
    start = time.time()
    response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload)
    elapsed_time = time.time() - start
    # Extracting and printing only the response content
    response_json = response.json()
    message_content = response_json['choices'][0]['message']['content']
    #print(f'file: {filepath}, message_content:\n {message_content}\n')

    output_file_path = os.path.join(output_dir, f"{os.path.splitext(file_name)[0]}.txt")
    with open(output_file_path, "w") as output_file:
        output_file.write(f"Image filename: {file_name}\n{message_content}\n")
        output_file.write(f"Processing time: {elapsed_time:.4f} seconds\n")
# Out:
# elaboro 000003_jpg.rf.d40443db19285b9a9946c11744788b4e.jpg elemento numero 1
# elaboro 000007_jpg.rf.b0dc72be378912149acb5cdff9467226.jpg elemento numero 2
# elaboro 000011_jpg.rf.49004c4398611bd1bb489d5e00bef241.jpg elemento numero 3
# elaboro 000038_jpg.rf.1130ff13d1eae8edfe3ac8062e85fcbc.jpg elemento numero 4
# elaboro 000047_jpg.rf.d84b4eef009d0b8940346cbfcb27aa37.jpg elemento numero 5
# elaboro 000059_jpg.rf.78dbc7b805060ce84bb5abe7390ea2ea.jpg elemento numero 6
# elaboro 000074_jpg.rf.a08d3e43f1e2ecf69a91575b31ef6350.jpg elemento numero 7
# elaboro 000080_jpg.rf.f71b3ca0d53611a5cafdadf815bf08f7.jpg elemento numero 8
# elaboro 000087_jpg.rf.ec9cc9dbbca8ace5ba6780a12d22842c.jpg elemento numero 9
# elaboro 000099_jpg.rf.5cfab9af85fab2f10af5bc6dba43a1a7.jpg elemento numero 10
# elaboro 000112_jpg.rf.8720f21b094b332ca0d232845c78bebb.jpg elemento numero 11
# elaboro 000139_jpg.rf.3adf28e0ab1eb59d719f487b7455fcbe.jpg elemento numero 12
# elaboro 000159_jpg.rf.14e4f61408d57cf1796e52b134937587.jpg elemento numero 13
# elaboro 000163_jpg.rf.93fc2da24e45edda4a1c82ae462b9ac5.jpg elemento numero 14
# elaboro 000180_jpg.rf.a949fac8a59945767ce537583d628791.jpg elemento numero 15
# elaboro 000188_jpg.rf.de07276f3b42baf694151e0e4a2ab667.jpg elemento numero 16
# elaboro 000190_jpg.rf.527c7e3efdf948f5d10358d75eb02a8b.jpg elemento numero 17
# elaboro 000193_jpg.rf.7b751276fe16df5be9e056ad916ab428.jpg elemento numero 18
# elaboro 000239_jpg.rf.9d6de3e306e3bd83e2aa9b8132a08a00.jpg elemento numero 19
# elaboro 000240_jpg.rf.e969caf8db860772ba66227ba07218bf.jpg elemento numero 20
# elaboro 000241_jpg.rf.6b1df94d33d8ae0a397c06ddb6897974.jpg elemento numero 21
# elaboro 000242_jpg.rf.aca73904c9feecc612dd00ba375ac2c0.jpg elemento numero 22
# elaboro 000243_jpg.rf.8365ff9ec85f01f67f98bd489c3f5a57.jpg elemento numero 23
# elaboro 000244_jpg.rf.4600979cc15d2693a04b29936476e87c.jpg elemento numero 24
# elaboro 000245_jpg.rf.f69ed86ce8828dedbf2fd4087cc2a479.jpg elemento numero 25
# elaboro 000246_jpg.rf.08e72b34c5c2272a36d07592c79e19ea.jpg elemento numero 26
# elaboro 000258_jpg.rf.19b512d88bdc48a3718b07dbca87320f.jpg elemento numero 27
# elaboro 000260_jpg.rf.66cf16d23c90a09f16c1349beb8d1a2e.jpg elemento numero 28
# elaboro 000263_jpg.rf.ea429cbc1e50fde426be08f1e564a225.jpg elemento numero 29
# elaboro 000267_jpg.rf.c866c5396621d9259734b4d86f98564c.jpg elemento numero 30
# elaboro 000272_jpg.rf.865aebe1e5f716ceeba593961c45f801.jpg elemento numero 31
# elaboro 000274_jpg.rf.afe38f0d22a4a8799c0917419ea149b7.jpg elemento numero 32
# elaboro 000276_jpg.rf.0fbd13ba97a0323ddfac7d066f88f8ae.jpg elemento numero 33
# elaboro 000279_jpg.rf.22b3c8142799941b0413a21d21dc3010.jpg elemento numero 34
# elaboro 000280_jpg.rf.bda7408107b9d28d6ea70e588200b980.jpg elemento numero 35
# elaboro 000282_jpg.rf.08f4d728fb25c4b95d5dc28f0387ca14.jpg elemento numero 36
# elaboro 000282_jpg.rf.306cacae4a7b8e0e620a9fc6905026ac.jpg elemento numero 37
# elaboro 000283_jpg.rf.18fa09d125cf38258ebf6921ce7a4651.jpg elemento numero 38
# elaboro 000284_jpg.rf.cc485ec07cad5cdf1fc6ea0b29d198e2.jpg elemento numero 39
# elaboro 000285_jpg.rf.656f0a0be3151a66a4ddf3542e3d442c.jpg elemento numero 40
# elaboro 000286_jpg.rf.acf34a7332fa093e27fd96211e15c4c5.jpg elemento numero 41
# elaboro 000287_jpg.rf.022a44d8f3ff58a8496183a8c4653e04.jpg elemento numero 42
# elaboro 000291_jpg.rf.abb8f6825f6076c29873878a266c0ff1.jpg elemento numero 43
# elaboro 000292_jpg.rf.9188aad07cb2fcb5eea05a8ccd7d0571.jpg elemento numero 44
# elaboro 000294_jpg.rf.d909224ec25b43f8d3bfdfb6a7b1e987.jpg elemento numero 45
# elaboro 000295_jpg.rf.09adab3668abff6289f7277c6c76f126.jpg elemento numero 46
# elaboro 000299_jpg.rf.7812dd5414b3823ac3e7907de28e1dd3.jpg elemento numero 47
# elaboro 000301_jpg.rf.20a5361e0a4555ae747fe88bd56e5bce.jpg elemento numero 48
# elaboro 000304_jpg.rf.fbfad07df2e0a7ca7bc5ed46edf986cf.jpg elemento numero 49
# elaboro 000307_jpg.rf.c49ea2880d676d3a75a035fef0fb035f.jpg elemento numero 50
# elaboro 000311_jpg.rf.af4966eb9d72b110a4a87599f92dcb28.jpg elemento numero 51
# elaboro 000314_jpg.rf.466c324c021dfcee755e03e0a973eae2.jpg elemento numero 52
# elaboro 000315_jpg.rf.17396080a9532b77c0c14dad23804adb.jpg elemento numero 53
# elaboro 000318_jpg.rf.3cff893fa86b55c3b40b61a52e7806d5.jpg elemento numero 54
# elaboro 000322_jpg.rf.5d93cfb3843c085142371ce59d3e98b6.jpg elemento numero 55
# elaboro 000324_jpg.rf.61839584480d0dbf303ef1a62c41d0f8.jpg elemento numero 56
# elaboro 000349_jpg.rf.78089df7e084c7d1d57908a12bf56d8a.jpg elemento numero 57
# elaboro 000350_jpg.rf.c3027d7a7d2ab5bc9f6c134e74b2462c.jpg elemento numero 58
# elaboro 000355_jpg.rf.56186e5007b9ecbfa08e12574b7ee344.jpg elemento numero 59
# elaboro 000356_jpg.rf.4b010b49d50c8b228019320d4d03a51e.jpg elemento numero 60
# elaboro 000401_jpg.rf.cb52fd90af8a489593369012425eea63.jpg elemento numero 61
# elaboro 000405_jpg.rf.1e6aeb42a76c8daa89120f87d4098caa.jpg elemento numero 62
# elaboro 000432_jpg.rf.c94f6f592356abe77319eccc3d3123a3.jpg elemento numero 63
# elaboro 000441_jpg.rf.25f9dbd918810c6179c8d847267533c0.jpg elemento numero 64
# elaboro 000443_jpg.rf.afd23c6920e3751fa6163466bae9434a.jpg elemento numero 65
# elaboro 000448_jpg.rf.dbb8911a70d9eb5371af5346a571a90d.jpg elemento numero 66
# elaboro 000461_jpg.rf.747ddf7918139680d3fc3e91e990e263.jpg elemento numero 67
# elaboro 000470_jpg.rf.e06dfb039e34543970920c34c942771a.jpg elemento numero 68
# elaboro 000474_jpg.rf.a73d3e3dd79d71b38cdf99faa95a04d3.jpg elemento numero 69
# elaboro 000475_jpg.rf.4155b2aa92dd47b59e0fd3e5be82d0d4.jpg elemento numero 70
# elaboro 000479_jpg.rf.93ff500f666d0761080fb990f0bd59ac.jpg elemento numero 71
# elaboro 000480_jpg.rf.215e1cebd70370e62c4c4326a8e1a3ee.jpg elemento numero 72
# elaboro 000482_jpg.rf.341858fccd514bf108b16307b3601d8e.jpg elemento numero 73
# elaboro 000483_jpg.rf.bf0309340b8c526f486c315a4c0abe2d.jpg elemento numero 74
# elaboro 000484_jpg.rf.5c56c8b682e829beb4515f9f5da89047.jpg elemento numero 75
# elaboro 000487_jpg.rf.02447176714a3516b23341d208be0c02.jpg elemento numero 76
# elaboro 000489_jpg.rf.728a41de13ca061d5b74e11a88905331.jpg elemento numero 77
# elaboro 000490_jpg.rf.df50ad499a82bf312eb65496dcd24b9f.jpg elemento numero 78
# elaboro 000493_jpg.rf.edc107361a165d085dbf839f84377460.jpg elemento numero 79
# elaboro 000494_jpg.rf.57a3d8a5b1b38f62195da8ebbea0d85c.jpg elemento numero 80
# elaboro 000498_jpg.rf.6550bca3b67fd036d251f1f7b919928b.jpg elemento numero 81
# elaboro 000499_jpg.rf.ee0eee20eefd4b3f12dbfac53c0dd13e.jpg elemento numero 82
# elaboro 000501_jpg.rf.e580b3c83c439a06343f76468e357d57.jpg elemento numero 83
# elaboro 000505_jpg.rf.5b216bec19588be84b271f5247d5b3bc.jpg elemento numero 84
# elaboro 000507_jpg.rf.ec3e5ebfb84d0e8118e45d1eceb592cf.jpg elemento numero 85
# elaboro 000508_jpg.rf.8e80d71396d98d01599371175b1ca54b.jpg elemento numero 86
# elaboro 000509_jpg.rf.d2c86e90786008613d5f4588645d7f01.jpg elemento numero 87
# elaboro 000510_jpg.rf.1c988ca6c8a43d564795333c3765180e.jpg elemento numero 88
# elaboro 000511_jpg.rf.b58f1c01fcf74fdf7cfa769cb34ae4a8.jpg elemento numero 89
# elaboro 000513_jpg.rf.ed0cfaa117918aa9dfd65e216e8aaebb.jpg elemento numero 90
# elaboro 000514_jpg.rf.09e0a1fa4b7f92608c4540d4c9b066e7.jpg elemento numero 91
# elaboro 000515_jpg.rf.a3f9b99000446b500859a41d8e59271c.jpg elemento numero 92
# elaboro 000516_jpg.rf.5824e67e9c5f75c60807384061c8b1f2.jpg elemento numero 93
# elaboro 000517_jpg.rf.a81010dc52953c31a635440cbe8a923f.jpg elemento numero 94
# elaboro 000518_jpg.rf.39fc76fafe82d72163aed86e0530a2a4.jpg elemento numero 95
# elaboro 000521_jpg.rf.5355e0595746957c21a2274f4d3ab3f5.jpg elemento numero 96
# elaboro 000521_jpg.rf.e1335e7c8682466c66785ace21cb49c5.jpg elemento numero 97
# elaboro 000525_jpg.rf.6db07cb64ae4446f9503d6d25be94d10.jpg elemento numero 98
# elaboro 000528_jpg.rf.83c8ef71c8885cfe69e94306a7dbafc2.jpg elemento numero 99
# elaboro 000529_jpg.rf.1b0658063e15c0b5505f215b73de9c7b.jpg elemento numero 100
# elaboro 000532_jpg.rf.0fcfce2f2d287986eae383b367411b0d.jpg elemento numero 101
# elaboro 000533_jpg.rf.f46922de10db39053120f768cf331295.jpg elemento numero 102
# elaboro 000534_jpg.rf.2250634e916178d3ace62c3e4fbb1cb6.jpg elemento numero 103
# elaboro 000535_jpg.rf.0b3a88375d9e065f49a8028c4a3e6416.jpg elemento numero 104
# elaboro 000536_jpg.rf.5da2000be396e8a9218c3c23512a6ea5.jpg elemento numero 105
# elaboro 000538_jpg.rf.5121d2629d787c458815e03c44343cbf.jpg elemento numero 106
# elaboro 000541_jpg.rf.5335916e0c7e78b582a1dbf070740de8.jpg elemento numero 107
# elaboro 000542_jpg.rf.cd7655ec5ecbeb46230472ca196d7a76.jpg elemento numero 108
# elaboro 000543_jpg.rf.65bc9df0ec92358124942fc6fbb83efd.jpg elemento numero 109
# elaboro 000544_jpg.rf.4c3b01b0ce6a0ece2038e69542a4f0d0.jpg elemento numero 110
# elaboro 000550_jpg.rf.045dc61db4051f00398ad2d2ff720b8d.jpg elemento numero 111
# elaboro 000552_jpg.rf.5afcd0a9cf4f2890b750cb4fe721166b.jpg elemento numero 112
# elaboro 000554_jpg.rf.1577206e11b2e6878e739defeb31d758.jpg elemento numero 113
# elaboro 000555_jpg.rf.6f9000b0bcc268c081e6bb21fa9a9ef7.jpg elemento numero 114
# elaboro 000555_jpg.rf.e05ee9216dac72330fd14206cb2e8567.jpg elemento numero 115
# elaboro 000556_jpg.rf.4144f29122c626ab41ff66dc0c06258a.jpg elemento numero 116
# elaboro 000560_jpg.rf.2a1f20945de523150f7a46a8f84a8e5c.jpg elemento numero 117
# elaboro 000564_jpg.rf.92099f747ff932b0143b02a591183ae1.jpg elemento numero 118
# elaboro 000567_jpg.rf.765151e1bdefa004bf6dbe3e2a121304.jpg elemento numero 119
# elaboro 000572_jpg.rf.4bda4c8fc54c632d50327231428fed2d.jpg elemento numero 120
# elaboro 000583_jpg.rf.2600199bc9be306435327a48960c3ae0.jpg elemento numero 121
# elaboro 000594_jpg.rf.d2d5d5ea74f58a9dbd11a0f5c3192549.jpg elemento numero 122
# elaboro 000598_jpg.rf.acaa31f526bea3416c984ff22a208ae3.jpg elemento numero 123
# elaboro 000645_jpg.rf.aba45d945ada85e6c6115f4959c0249c.jpg elemento numero 124
# elaboro 000663_jpg.rf.7ad60bf079f9ba5be54a4f73f53ff49b.jpg elemento numero 125
# elaboro 000674_jpg.rf.0a77da5fd5aeddc72b44226c21af40a9.jpg elemento numero 126
# elaboro 000687_jpg.rf.6834628dee96d0a251735c889c935770.jpg elemento numero 127
# elaboro 000689_jpg.rf.f15b76cdb7ed41ba23b18b6a6c214a34.jpg elemento numero 128
# elaboro 000692_jpg.rf.c6c5d28f6056401573e02f9858bd1fc7.jpg elemento numero 129
# elaboro 000702_jpg.rf.fc8ee9b606ea7c267b83c1b4866df022.jpg elemento numero 130
# elaboro 000708_jpg.rf.0a33eef1752f95c55f40d6ee8ca6e5a0.jpg elemento numero 131
# elaboro 000709_jpg.rf.3e4fbbc301f7376b907e8c1eaaafbe52.jpg elemento numero 132
# elaboro 000717_jpg.rf.1de2c5cb058d1552ab14c45e06f71e8f.jpg elemento numero 133
# elaboro 000741_jpg.rf.d1ff4086db9566b4d67619e8cae91090.jpg elemento numero 134
# elaboro 000742_jpg.rf.58ca9862df8ced3516a40868a40ec398.jpg elemento numero 135
# elaboro 000750_jpg.rf.c1c0d1c49f11b75d9e1084261ad02f9f.jpg elemento numero 136
# elaboro 000752_jpg.rf.c914cf0c8687397a2b8c7213947ee38a.jpg elemento numero 137
# elaboro 000755_jpg.rf.7a17f34065d09122684595265ef6269f.jpg elemento numero 138
# elaboro 000758_jpg.rf.5395cca8b2cc5e008315f52a9dc528d9.jpg elemento numero 139
# elaboro 000759_jpg.rf.c2ee78471a790566a9fe0b09b9c31ddf.jpg elemento numero 140
# elaboro 000763_jpg.rf.45c5e4ee60abacec6d91e0a9fb699d87.jpg elemento numero 141
# elaboro 000764_jpg.rf.f1a4476fa731f52ab22bca634f841cfd.jpg elemento numero 142
# elaboro 000776_jpg.rf.8a95540e4bc7a1846d4ee847bb028daa.jpg elemento numero 143
# elaboro 000777_jpg.rf.376e9e031db0c54d91545556b65b1e2e.jpg elemento numero 144
# elaboro 000787_jpg.rf.55dc06ebe68910072c1d615d5d0be70d.jpg elemento numero 145
# elaboro 000790_jpg.rf.9a8218e4b98aee7206834cbcdd1b9cee.jpg elemento numero 146
# elaboro 000791_jpg.rf.50d95a38b58d3e86c438db3f5bf17232.jpg elemento numero 147
# elaboro 000801_jpg.rf.ef46d37e2695162969beb54c7f6b786f.jpg elemento numero 148
# elaboro 000816_jpg.rf.57d7548fc1e14604bf7071e537d26f20.jpg elemento numero 149
# elaboro 000818_jpg.rf.81b8e050601f42a37722ac4ec46f93a3.jpg elemento numero 150
# elaboro 000821_jpg.rf.0d8dcf01c488228bca4c0652fcc2b296.jpg elemento numero 151
# elaboro 000823_jpg.rf.8ce455885f1fb3d941aecf833793a304.jpg elemento numero 152
# elaboro 000824_jpg.rf.e6b66134eae11050b43ccf04de40d223.jpg elemento numero 153
# elaboro 000828_jpg.rf.964405712d8fb7bcdebd86f1dab82406.jpg elemento numero 154
# elaboro 000830_jpg.rf.3b4cbbc90a4808d14be0245c77efc468.jpg elemento numero 155
# elaboro 000833_jpg.rf.bbe3f08a0dc2db2c5dfe3b9c6fecb150.jpg elemento numero 156
# elaboro 000836_jpg.rf.b37f05964df054983eecb1b2d0758a70.jpg elemento numero 157
# elaboro 000837_jpg.rf.52828ef9fa0b922a87757f94ab2d4ebd.jpg elemento numero 158
# elaboro 000838_jpg.rf.008223cc170bb52cb9e4b9673452cc37.jpg elemento numero 159
# elaboro 000839_jpg.rf.8494a99328272974e67fa8df7c9c98c5.jpg elemento numero 160
# elaboro 000840_jpg.rf.452f6f418cb423387452f62085100005.jpg elemento numero 161
# elaboro 000842_jpg.rf.38b5cc8a84bf10b3faed827207867f65.jpg elemento numero 162
# elaboro 000845_jpg.rf.f74d8c4058eebc8dfd9d04dfbcf8b542.jpg elemento numero 163
# elaboro 000848_jpg.rf.3f261f6b891bb939de97173a4ed63782.jpg elemento numero 164
# elaboro 000849_jpg.rf.4ff0b956d8de803845e6bd04bbea8007.jpg elemento numero 165
# elaboro 000850_jpg.rf.b1bfd4578cb65bc76d83edd78686cd8e.jpg elemento numero 166
# elaboro 000851_jpg.rf.865ec0fdd5a5a253605215a9b1356118.jpg elemento numero 167
# elaboro 000852_jpg.rf.3c957c8c954c2bc5caf472ddeff99b54.jpg elemento numero 168
# elaboro 000853_jpg.rf.33667cbd2c15fe1fcf5353230b94ceeb.jpg elemento numero 169
# elaboro 000854_jpg.rf.f736fae988dbdc50908189b30827cc68.jpg elemento numero 170
# elaboro 000855_jpg.rf.5a6dd92038761bbf41916f24617e761f.jpg elemento numero 171
# elaboro 000856_jpg.rf.2f8a91012778ff2e03377e5798d19068.jpg elemento numero 172
# elaboro 000857_jpg.rf.931a4b7594cb80a464d0d1aeb628f3e5.jpg elemento numero 173
# elaboro 000858_jpg.rf.996bd13ebf681ed87677d099ce8cd53d.jpg elemento numero 174
# elaboro 000859_jpg.rf.811a1f5b8aa79ebc33cc81e5cd69dc73.jpg elemento numero 175
# elaboro 000860_jpg.rf.713286bf4e5671d8bf9abe0ba29b6591.jpg elemento numero 176
# elaboro 000861_jpg.rf.31301bf5d05dd6827a82970077dd7cc7.jpg elemento numero 177
# elaboro 000862_jpg.rf.301e9ea501143ab3b5f98db232a54d83.jpg elemento numero 178
# elaboro 000863_jpg.rf.fab2a413f1e29245c91ff77530ab3795.jpg elemento numero 179
# elaboro 000864_jpg.rf.62a0872e4a272acb31c63c1f8938368f.jpg elemento numero 180
# elaboro 000865_jpg.rf.7043e73f7ed98cb4311301f78d3e619d.jpg elemento numero 181
# elaboro 000866_jpg.rf.4473b3c177495022b2c277c3e03647c8.jpg elemento numero 182
# elaboro 000867_jpg.rf.23939563e3d3a2c00d0ab6ed39b1002e.jpg elemento numero 183
# elaboro 000868_jpg.rf.dd9a173d001b5c0e377e443aa7074988.jpg elemento numero 184
# elaboro 000869_jpg.rf.ffbab464b05abcc8a2f3be2acddc470f.jpg elemento numero 185
# elaboro 000870_jpg.rf.fbe983425d06c068334e2e10b9f86251.jpg elemento numero 186
# elaboro 000871_jpg.rf.9606ec507a3e6ad0e0c89fef3cd29925.jpg elemento numero 187
# elaboro 000872_jpg.rf.b7ad141b3a92abf1f246dd60850bbe1a.jpg elemento numero 188
# elaboro 000873_jpg.rf.6e7dbf32247c4877b1c65e9d82aea15c.jpg elemento numero 189
# elaboro 000874_jpg.rf.e33242b468c1be9fb0df340c1fa223fd.jpg elemento numero 190
# elaboro 000875_jpg.rf.ebd550083d656371f7a42a1f67d7111e.jpg elemento numero 191
# elaboro 000876_jpg.rf.39f575793a47cd6db05abf7d9ed02f72.jpg elemento numero 192
# elaboro 000877_jpg.rf.b5f4d3ef14246264464e57136ef9486e.jpg elemento numero 193
# elaboro 000878_jpg.rf.222be11443d19be0835160d04b7e15f7.jpg elemento numero 194
# elaboro 000879_jpg.rf.035d45b3ea800ac9e9cb69c3277d7e1c.jpg elemento numero 195
# elaboro 000880_jpg.rf.20717b29ba88ed22afecfe259a5265a7.jpg elemento numero 196
# elaboro 000882_jpg.rf.2e1fa1398e05c1a323da60c3b1da79cd.jpg elemento numero 197
# elaboro 000883_jpg.rf.78bf42ac4cd05f3ce4fa36ff58c8882f.jpg elemento numero 198
# elaboro 000885_jpg.rf.b8cda7cf158197127316a02de2050c7e.jpg elemento numero 199
# elaboro 000886_jpg.rf.36ed6f10eb01c55f76d875b87eab9b22.jpg elemento numero 200
# elaboro 000887_jpg.rf.9d80fd39c5b51ad96e21c1299a70b2af.jpg elemento numero 201
# elaboro 000888_jpg.rf.06f05a48a6abc4eb7b81c239adb51645.jpg elemento numero 202
# elaboro 000889_jpg.rf.81ab6c340b320a6cde7576f62291b0ea.jpg elemento numero 203
# elaboro 000890_jpg.rf.5f6a58aafd42270eee37688702d4a6d1.jpg elemento numero 204
# elaboro 000891_jpg.rf.599b9e92f46214dcfde80b5174fc7327.jpg elemento numero 205
# elaboro 000892_jpg.rf.e42e63b13e7937f7d29c8617083d872b.jpg elemento numero 206
# elaboro 000893_jpg.rf.f543326a1f50ff7946aea1e9bcb167b8.jpg elemento numero 207
# elaboro 000894_jpg.rf.0b76eee9a2055d8867f4fcbb8ebe4460.jpg elemento numero 208
# elaboro 000896_jpg.rf.e7a72fa3cc78c46db4edef3c93d9eefe.jpg elemento numero 209
# elaboro 000897_jpg.rf.f90e4c0367c35c11ba6f4f4cb53cde02.jpg elemento numero 210
# elaboro 000898_jpg.rf.79cc1bafeab2be65d53469eed0acffb3.jpg elemento numero 211
# elaboro 000899_jpg.rf.3d25d335ae4b63e5eff9b518260505bf.jpg elemento numero 212
# elaboro 000903_jpg.rf.97714b48a6687b9a125f85670d15404f.jpg elemento numero 213
# elaboro 000904_jpg.rf.1dd86cd8d9660d70a03105fa1c6d58b5.jpg elemento numero 214
# elaboro 000905_jpg.rf.cfb066f543e1026ef3568793c2c67414.jpg elemento numero 215
# elaboro 000906_jpg.rf.76462921da962a794f8d916496d4ffb4.jpg elemento numero 216
# elaboro 000908_jpg.rf.04f271f35c7b18b8591c7355fd5b5664.jpg elemento numero 217
# elaboro 000909_jpg.rf.c105df869f8d4801cd179a61cfce2062.jpg elemento numero 218
# elaboro 000912_jpg.rf.194572a86502c10b31732afe6340ff41.jpg elemento numero 219
# elaboro 000916_jpg.rf.615c1bec95a3b51cf060ee745a5684b1.jpg elemento numero 220
# elaboro 000921_jpg.rf.02b60b91ffcaa5e604a03e4a0f3c7af6.jpg elemento numero 221
# elaboro 000922_jpg.rf.d079a63081088f5c1602aa34927b6997.jpg elemento numero 222
# elaboro 000923_jpg.rf.28abee7a2647a6a82ca507ed4b735e60.jpg elemento numero 223
# elaboro 000924_jpg.rf.ca00e12200f4c1dc190a5044df8da98e.jpg elemento numero 224
# elaboro 000926_jpg.rf.fa4283985a614373a82751db89609382.jpg elemento numero 225
# elaboro 000927_jpg.rf.ce5f63e6540ecb07127fcaddce1d14f1.jpg elemento numero 226
# elaboro 000928_jpg.rf.5b3253e71a70c82056ad5fab9e127390.jpg elemento numero 227
# elaboro 000929_jpg.rf.ac3874cadd9a2de8e487fb0b220e58bf.jpg elemento numero 228
# elaboro 000931_jpg.rf.9cc94e1d0fe6f1de09216c042bed6c55.jpg elemento numero 229
# elaboro 000932_jpg.rf.bcf9f64c19e92f6efc3c08da640b31f1.jpg elemento numero 230
# elaboro 000934_jpg.rf.5bf2e4d7a25e4bb38646966aea573ad1.jpg elemento numero 231
# elaboro 000936_jpg.rf.b218d1b1874892086021f9f342b80a82.jpg elemento numero 232
# elaboro 000940_jpg.rf.3a9eb943a854a887a94199744e946e54.jpg elemento numero 233
# elaboro 000941_jpg.rf.ef449bde626dd04ad64301c6f4956656.jpg elemento numero 234
# elaboro 000942_jpg.rf.91a799efc495e5ba684630f6f4898357.jpg elemento numero 235
# elaboro 000945_jpg.rf.d0499b4558a42911988dde507cfe77d9.jpg elemento numero 236
# elaboro 000948_jpg.rf.a54efddd2ff919c7338b4e5683e33fe7.jpg elemento numero 237
# elaboro 000949_jpg.rf.ccaa79aa10c96d3f171fd701e0ade17a.jpg elemento numero 238
# elaboro 000950_jpg.rf.8d8e6f27930de00bc095e89ffee3a9ff.jpg elemento numero 239
# elaboro 000952_jpg.rf.d567ca9a8b4570b59731c6f0d79a066a.jpg elemento numero 240
# elaboro 000953_jpg.rf.578b585e5e0dbf9d9face2a5b95aa402.jpg elemento numero 241
# elaboro 000956_jpg.rf.a391949c0199d3eea142a95afffdf628.jpg elemento numero 242
# elaboro 000957_jpg.rf.743258b670e732ee5ba76d674a9b1e10.jpg elemento numero 243
# elaboro 000959_jpg.rf.7a071ee5cccc1e4117970511eb618db3.jpg elemento numero 244
# elaboro 000960_jpg.rf.0ceab74f17073146b007d68be0c834cd.jpg elemento numero 245
# elaboro 000961_jpg.rf.7a96ab67f1066b546b064893c57efb4b.jpg elemento numero 246
# elaboro 000962_jpg.rf.8eef8002595f899a6c47edb63005fb64.jpg elemento numero 247
# elaboro 000965_jpg.rf.e884db4e645e2fbda481545e39efea46.jpg elemento numero 248
# elaboro 000966_jpg.rf.a9b80d2619128bb6377e517bcc73c748.jpg elemento numero 249
# elaboro 000968_jpg.rf.f98ab1c9bc0cbe48f2a165ea36175107.jpg elemento numero 250
# elaboro image_from_china-1723-_jpg.rf.a2d8e0342df6da27a22298dd63284fd9.jpg elemento numero 251
# elaboro image_from_china-261-_jpg.rf.f00ea5e64b325281b2f74fb304d7d8cd.jpg elemento numero 252
# elaboro image_from_china-270-_jpg.rf.3e3324c626a451fba3dc7bf5e94fb935.jpg elemento numero 253
# elaboro image_from_china-289-_jpg.rf.04f01825914e270c10a88a94715afbdb.jpg elemento numero 254
# elaboro image_from_china-341-_jpg.rf.29df58925e6d4af3b5e6e338bd9616bb.jpg elemento numero 255
# elaboro image_from_china-341-_jpg.rf.2e349776f8b20f62b215348757b39ead.jpg elemento numero 256
# elaboro image_from_china-362-_jpg.rf.af15b5924c6eb0b30581aba4823d74be.jpg elemento numero 257
# elaboro image_from_china-371-_jpg.rf.86ca50d8772689c29987fa66accc1af3.jpg elemento numero 258
# elaboro image_from_china-391-_jpg.rf.d793425537225798464f26272e3322fb.jpg elemento numero 259
# elaboro image_from_china-417-_jpg.rf.8b663683fe5e6c1ca5b0155e60566548.jpg elemento numero 260
# elaboro image_from_china-457-_jpg.rf.02f5ff5b7c447c2dec8965cf009be76e.jpg elemento numero 261
# elaboro image_from_china-475-_jpg.rf.bafedf7a5cacbece2eaa5ff15d1268cb.jpg elemento numero 262
# elaboro image_from_china-524-_jpg.rf.5d7ae31c91eb7d8346225ed34bd721fd.jpg elemento numero 263
# elaboro image_from_china-560-_jpg.rf.269e125cb0501b419b7cc87d36621f7d.jpg elemento numero 264
# elaboro image_from_china-578-_jpg.rf.77dafaa87747b66b032fb6a884b92c0e.jpg elemento numero 265
# elaboro image_from_china-578-_jpg.rf.992b508fc3e80befedc02c6c8e7aef27.jpg elemento numero 266
# elaboro image_from_china-631-_jpg.rf.f08be4f0d2a20fa64d43e6f19e4d4e3a.jpg elemento numero 267
# elaboro image_from_china-744-_jpg.rf.0cff8c20e69453d1fd5d3cd5bc97b50b.jpg elemento numero 268
# elaboro ppe_0000_jpg.rf.05aa024f36351fa65dd34d9f5be5db4e.jpg elemento numero 269
# elaboro ppe_0018_jpg.rf.9c86ac702a3bb3e4d19b5228b5e8a2f8.jpg elemento numero 270
# elaboro ppe_0033_jpg.rf.cbfb0249ac925b12d351a5ecb4d65fc6.jpg elemento numero 271
# elaboro ppe_0036_jpg.rf.b12dfa9de7d26747a3070907b9159f64.jpg elemento numero 272
# elaboro ppe_0051_jpg.rf.fc873407be338e7bbffd9f736c2b90f9.jpg elemento numero 273
# elaboro ppe_0128_jpg.rf.cf35c9e2bbe4675536dfab6d4fc833d6.jpg elemento numero 274
# elaboro ppe_0154_jpg.rf.a35d0a60c2a5881a92f117945a68e4ba.jpg elemento numero 275
# elaboro ppe_0397_jpg.rf.72c248826a59e8a1427fd45a519b270b.jpg elemento numero 276
# elaboro ppe_0931_jpg.rf.b9361d4d51c09514648dcbc490baa28f.jpg elemento numero 277
# elaboro ppe_0994_jpg.rf.ea6bac492d936a77a6af7b09aaed8ab0.jpg elemento numero 278
# elaboro ppe_1037_jpg.rf.f0a034968b50a638db9c1ca60fa8fd30.jpg elemento numero 279
# elaboro ppe_1038_jpg.rf.b76cb79dcc4614737e5e6aa8ece54937.jpg elemento numero 280
# elaboro ppe_1056_jpg.rf.07b14d5edfbdef5f93bed73da1ca4b3c.jpg elemento numero 281
# elaboro ppe_1074_jpg.rf.170fd2819987ddfabbb4e0fcaa645db4.jpg elemento numero 282
# elaboro ppe_1075_jpg.rf.6f07e605d995a87a7937b75063011968.jpg elemento numero 283
# elaboro ppe_1082_jpg.rf.71423d3f831606f66cec3e3d6c650183.jpg elemento numero 284
# elaboro ppe_1094_jpg.rf.f88d842eabd77aa76a70cf4ea884dc41.jpg elemento numero 285
# elaboro ppe_1098_jpg.rf.93ca53468305d99cfab84624a92d3ba5.jpg elemento numero 286
# elaboro ppe_1102_jpg.rf.6b7992b3a78883a0747100d10e51f005.jpg elemento numero 287
# elaboro ppe_1102_jpg.rf.d840f3470a4235aa677fef709a86ea06.jpg elemento numero 288
# elaboro ppe_1105_jpg.rf.0129b2a4b3e14247aab1c7924d9da271.jpg elemento numero 289
# elaboro ppe_1122_jpg.rf.09a7b20b268d68678e386d1a67b526e7.jpg elemento numero 290
# elaboro ppe_1141_jpg.rf.014ba97a593a311a869cef768894087d.jpg elemento numero 291
# elaboro ppe_1149_jpg.rf.9aa17a22684903510c94c747bb4f4c20.jpg elemento numero 292
# elaboro ppe_1159_jpg.rf.62612d8c22c65690d98ffa4a38a0f1d0.jpg elemento numero 293
# elaboro ppe_1173_jpg.rf.b259420c4e49a956175bc0024cbe4f2f.jpg elemento numero 294
# elaboro ppe_1199_jpg.rf.73c9ea04d97b47d1b028a3db313c7416.jpg elemento numero 295
# elaboro ppe_1204_jpg.rf.b05466885036032f28ce7c971d3435fa.jpg elemento numero 296
# elaboro ppe_1238_jpg.rf.75ca1aa2426912ec5a458fb30cbbfa85.jpg elemento numero 297
# elaboro ppe_1246_jpg.rf.e2948ccb5207ae7a57f37baeb4f8792e.jpg elemento numero 298
# elaboro ppe_1262_jpg.rf.677b983af8eecf1312e383f9835b083b.jpg elemento numero 299
# elaboro ppe_1266_jpg.rf.d05c7f1b8e7e0259d9f2db2e7e1ae268.jpg elemento numero 300
# elaboro ppe_1270_jpg.rf.0aac7475c0731464cc574a01c57d2396.jpg elemento numero 301
# elaboro ppe_1279_jpg.rf.ded61cfbeff7000f7c1049ec4d04f733.jpg elemento numero 302
# elaboro ppe_1289_jpg.rf.aef3ba1622b323b5016d2ac04ba4d2f6.jpg elemento numero 303
# elaboro ppe_1302_jpg.rf.889e0b92314e880ca743ab799214021c.jpg elemento numero 304
# elaboro ppe_1303_jpg.rf.5fc08402c38119dfaf3db2a9d89836cf.jpg elemento numero 305
# elaboro ppe_1304_jpg.rf.4764d98c931cbbbaaa69b1fe998980e5.jpg elemento numero 306
# elaboro ppe_1324_jpg.rf.b0209696ad2a4ca44d39c0e5cb771b19.jpg elemento numero 307
# elaboro ppe_1328_jpg.rf.860a32aeb7abd308d5a0e8d355e6076a.jpg elemento numero 308

# %%
mapping = [
    ("Worker", "People:"),
    ("no-vest", "no-Reflective_vests:"),
    ("no-shoes", "no-Security_boots:"),
    ("no-gloves", "no-Gloves:"),
    ("no-helmet", "no-Hard_hats:"),
]

def calculate_metrics(ground_truth, predictions, mapping):
    metrics = {"TP": 0, "FP": 0, "FN": 0}
    for class_name, model_key in mapping:
        if model_key is None:
            pred_count = 0  # No prediction for this class
        else:
            pred_count = predictions.get(model_key, 0)
        true_count = ground_truth.get(class_name, 0)

        if pred_count == true_count:
            metrics["TP"] += true_count
        elif true_count > pred_count:
            metrics["TP"] += pred_count
            metrics["FN"] += (true_count - pred_count)
        else:
            metrics["TP"] += true_count
            metrics["FP"] += (pred_count - true_count)

    return metrics

def calculate_metrics_per_DPI(ground_truth, predictions, mapping, dpi):
    metrics = {"TP": 0, "FP": 0, "FN": 0}
    for class_name, model_key in mapping:
        if model_key is None or dpi != model_key.strip(":"):
            continue  # Skip if the current class does not match the DPI we're focusing on

        pred_count = predictions.get(model_key, 0)
        true_count = ground_truth.get(class_name, 0)

        if pred_count == true_count:
            metrics["TP"] += true_count
        elif true_count > pred_count:
            metrics["TP"] += pred_count
            metrics["FN"] += (true_count - pred_count)
        else:
            metrics["TP"] += true_count
            metrics["FP"] += (pred_count - true_count)

    return metrics



def read_ground_truth(file_path):
    ground_truth = {}
    with open(file_path, 'r') as f:
        for line in f:
            elements = line.split()
            class_id = int(elements[0])
            if class_id == 2:
                ground_truth["no-gloves"] = ground_truth.get("no-gloves", 0) + 1
            elif class_id == 3:
                ground_truth["no-helmet"] = ground_truth.get("no-helmet", 0) + 1
            elif class_id == 6:
                ground_truth["Worker"] = ground_truth.get("Worker", 0) + 1
            elif class_id == 4:
                ground_truth["no-shoes"] = ground_truth.get("no-shoes", 0) + 1
            elif class_id == 5:
                ground_truth["no-vest"] = ground_truth.get("no-vest", 0) + 1
    return ground_truth


def extract_json_from_file(file_path):
    result = {}
    found = False
    with open(file_path, 'r') as file:
        lines = file.readlines()
        for line in lines:
            line = line.lstrip()
            if line.startswith('-'):
                DPI = ''
                found = True
                words = line.split()
                flag = True
                for word in words:
                    if not flag:
                        break
                    if word == 'People:' or word == 'no-Gloves:' or word == 'no-Security_boots:' or word == 'no-Reflective_vests:' or word == 'no-Hard_hats:':
                        DPI = word
                        found = True
                    if word.isdigit():
                        result[DPI] = result.get(DPI, 0) + int(word)
                        flag = False
                    if word == 'Yes':
                        result[DPI] = result.get(DPI, 0) + 1
                        flag = False
                    if word == 'No' or word.lower() == 'not':
                        result[DPI] = result.get(DPI, 0)
                        flag = False
        if not found:
            result['People:'] = result.get('People:', 0)
            result['no-Gloves:'] = result.get('no-Gloves:', 0)
            result['no-Security_boots:'] = result.get('no-Security_boots:', 0)
            result['no-Reflective_vests:'] = result.get('no-Reflective_vests:', 0)
            result['no-Hard_hats:'] = result.get('no-Hard_hats:', 0)
    #print(f'result: {result}')
    return result



def filter_greater_than_zero(data):
    return {key: value for key, value in data.items() if value > 0}

def calculate_classification_metrics(metrics):
    TP = metrics["TP"]
    FP = metrics["FP"]
    FN = metrics["FN"]

    accuracy = TP / (TP + FP + FN) if (TP + FP + FN) > 0 else 0
    precision = TP / (TP + FP) if (TP + FP) > 0 else 0
    recall = TP / (TP + FN) if (TP + FN) > 0 else 0
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    return {
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1_score": f1_score
    }

def save_metrics_to_file(metrics, output_folder, file_name):
    output_path = os.path.join(output_folder, f"{file_name}_metrics.json")
    with open(output_path, 'w') as f:
        json.dump(metrics, f, indent=4)
    #print(f"Metrics saved to {output_path}")

def calculate_final_metrics(all_metrics):
    total_accuracy = 0
    total_precision = 0
    total_recall = 0
    total_f1_score = 0
    n = len(all_metrics)
    # Somma i valori delle metriche per ciascun file
    for metric in all_metrics:
        total_accuracy += metric['accuracy']
        total_precision += metric['precision']
        total_recall += metric['recall']
        total_f1_score += metric['f1_score']


    # Calcola la media per ciascuna metrica
    final_metrics = {
        "final_accuracy": total_accuracy / n,
        "final_precision": total_precision / n,
        "final_recall": total_recall / n,
        "final_f1_score": total_f1_score / n
    }
    return final_metrics

# %%
import json
import os

ground_truth_folder = "PPE-detection-no-ppe-v2/test/labels"
predictions_folder = "output/gpt4o/working/test_set"
output_folder = "output/gpt4o/working/metrics_output"
output_folder_final = "output/gpt4o/working/metrics_output_final"
os.makedirs(output_folder, exist_ok=True)
os.makedirs(output_folder_final, exist_ok=True)
DPI = ['People', 'no-Hard_hats', 'no-Gloves', 'no-Reflective_vests', 'no-Security_boots']

gt_files = sorted(os.listdir(ground_truth_folder))
pred_files = sorted(os.listdir(predictions_folder))
all_metrics = []
for gt_file, pred_file in zip(gt_files, pred_files):
    #print(gt_file, pred_file)
    base_filename = os.path.splitext(pred_file)[0]
    #print(base_filename)
    gt_results = read_ground_truth(os.path.join(ground_truth_folder,gt_file))
    #print(f'gt: {gt_results}')
    data = extract_json_from_file(os.path.join(predictions_folder, pred_file))
    prediction_results = filter_greater_than_zero(data)
    #print(f'prediction: {prediction_results}\n')
    metrics = calculate_metrics(gt_results, prediction_results, mapping)
    final_metrics_per_image = calculate_classification_metrics(metrics)
    all_metrics.append(final_metrics_per_image)
final = calculate_final_metrics(all_metrics)
print(f'final metric: {final}')
save_metrics_to_file(final, output_folder_final, "final")

#########################################################################################################
final_ppes_metrics = {
    'People': {
        'Accuracy': 0,
        'Precision': 0,
        'Recall': 0,
        'F1-Score': 0
    },
    'no-Hard_hats': {
        'Accuracy': 0,
        'Precision': 0,
        'Recall': 0,
        'F1-Score': 0
    },
    'no-Gloves': {
        'Accuracy': 0,
        'Precision': 0,
        'Recall': 0,
        'F1-Score': 0
    },
    'no-Reflective_vests': {
        'Accuracy': 0,
        'Precision': 0,
        'Recall': 0,
        'F1-Score': 0
    },
    'no-Security_boots': {
        'Accuracy': 0,
        'Precision': 0,
        'Recall': 0,
        'F1-Score': 0
    },
}
# Second part of the code to calculate per DPI metrics
gt_files = sorted(os.listdir(ground_truth_folder))
pred_files = sorted(os.listdir(predictions_folder))

# Iterate over each DPI type
for dpi in DPI:
    all_metrics_per_dpi = []  # Initialize a list to collect metrics for each DPI
    for gt_file, pred_file in zip(gt_files, pred_files):
        base_filename = os.path.splitext(pred_file)[0]

        # Read ground truth and predictions for the current image
        gt_results = read_ground_truth(os.path.join(ground_truth_folder, gt_file))
        data = extract_json_from_file(os.path.join(predictions_folder, pred_file))

        # Filter predictions with counts greater than zero
        prediction_results = filter_greater_than_zero(data)

        # Calculate per-image metrics for the current DPI
        metrics = calculate_metrics_per_DPI(gt_results, prediction_results, mapping, dpi)
        final_metrics_per_image = calculate_classification_metrics(metrics)
        all_metrics_per_dpi.append(final_metrics_per_image)

    # Calculate final averaged metrics for the current DPI
    final_dpi_metrics = calculate_final_metrics(all_metrics_per_dpi)
    print(f'final metric {dpi}: {final_dpi_metrics}')

    # Update the final PPE metrics dictionary with calculated values
    final_ppes_metrics[dpi]['Accuracy'] = final_dpi_metrics['final_accuracy']
    final_ppes_metrics[dpi]['Precision'] = final_dpi_metrics['final_precision']
    final_ppes_metrics[dpi]['Recall'] = final_dpi_metrics['final_recall']
    final_ppes_metrics[dpi]['F1-Score'] = final_dpi_metrics['final_f1_score']

# Save final PPEs metrics to file
output_file_path = os.path.join(output_folder_final, "final_ppes_metrics.json")
with open(output_file_path, 'w') as f:
    json.dump(final_ppes_metrics, f, indent=4)
# Out:
# final metric: {'final_accuracy': 0.6551302059058779, 'final_precision': 0.747347585968294, 'final_recall': 0.8260635905401282, 'final_f1_score': 0.7651634608511553}
# final metric People: {'final_accuracy': 0.8994594539977463, 'final_precision': 0.9274818780023135, 'final_recall': 0.9167827708006279, 'final_f1_score': 0.9181150809173393}
# final metric no-Hard_hats: {'final_accuracy': 0.2632640177283035, 'final_precision': 0.27847351061636777, 'final_recall': 0.2769982993197279, 'final_f1_score': 0.2734185010259554}
# final metric no-Gloves: {'final_accuracy': 0.46962631895309515, 'final_precision': 0.5906710119945414, 'final_recall': 0.5770072550105018, 'final_f1_score': 0.5459126223570253}
# final metric no-Reflective_vests: {'final_accuracy': 0.6199471283003558, 'final_precision': 0.6378461439672287, 'final_recall': 0.6476853999175428, 'final_f1_score': 0.6378215641240917}
# final metric no-Security_boots: {'final_accuracy': 0.17826505337248263, 'final_precision': 0.2473249423736436, 'final_recall': 0.193927123985852, 'final_f1_score': 0.20740205178998244}
